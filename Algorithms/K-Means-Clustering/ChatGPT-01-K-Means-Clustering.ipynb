# %%
import tensorflow as tf
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../../zData/Fish-Market/Fish.csv")

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = df.drop(['Species'], axis=1)
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=4)

# %%
df['cluster'] = kmeans.predict(X_scaled)

# %%
# Other Dark - 0a2e40
# Cozmo Dark - 06266f
# Sumo Dark - 06266f
# Cozmo Orange - ff7400
# Sumo Orange - ff7400
# Cozmo Light - 3894c4
# Cozmo Light - 47a6d9
# Sumo Light - 47a6d7

# https://seaborn.pydata.org/tutorial/color_palettes.html

custom_style = {'axes.facecolor': '#0a2e40', # 112d6c - less dark dark green
 'axes.edgecolor': '#ff7400',
 'axes.grid': True,
 'axes.axisbelow': True,
 'axes.labelcolor': '#ff7400',
 'figure.facecolor': '#0a2e40',
 'grid.color': '#47a6d7',
 'grid.linestyle': '-',
 'text.color': '#ff7400',
 'xtick.color': '#ff7400',
 'ytick.color': '#ff7400',
 'xtick.direction': 'out',
 'ytick.direction': 'out',
 'patch.edgecolor': '#ff7400',
 'patch.force_edgecolor': True,
 'image.cmap': 'YlOrBr',
 'font.color': '#ff7400',
 'font.family': ['sans-serif'],
 'font.sans-serif': ['Nunito Black',
  'Arial',
  'DejaVu Sans',
  'Liberation Sans',
  'Bitstream Vera Sans',
  'sans-serif'],
 'xtick.bottom': False,
 'xtick.top': False,
 'ytick.left': False,
 'ytick.right': False,
 'axes.spines.left': True,
 'axes.spines.bottom': True,
 'axes.spines.right': True,
 'axes.spines.top': True}
sns.set_style("darkgrid", rc=custom_style)

# %%
sns.scatterplot(x='Length1', y='Width', hue='cluster', data=df, palette='bright')
sns.pairplot(df, hue='cluster', palette="bright")

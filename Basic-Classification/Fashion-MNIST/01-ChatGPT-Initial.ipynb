# %% [markdown]
# # Fashion-MNIST Using OpenAI's ChatGPT
# I've done this sort of project before, but I wanted to do it using OpenAI's ChatGPT.
#
# I had to help a bit getting it to give the class_names, and it didn't want to do the validation split by default.
#
# But overall I literally copies and pasted the whole thing.
#
# YouTube link incoming later.

# %%
# Import TensorFlow and other libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the class names for the Fashion-MNIST dataset
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Split the training data into training and validation sets
x_val = x_train[:5000]
y_val = y_train[:5000]
x_train = x_train[5000:]
y_train = y_train[5000:]

# Normalize the pixel values
x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# %%
# Define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(x_train, y_train,
                    epochs=5,
                    validation_data=(x_val, y_val),
                    verbose=2)
# Out:
# Epoch 1/5
# 1719/1719 - 4s - loss: 0.5048 - accuracy: 0.8218 - val_loss: 0.3870 - val_accuracy: 0.8598 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1719/1719 - 4s - loss: 0.3795 - accuracy: 0.8643 - val_loss: 0.3581 - val_accuracy: 0.8708 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1719/1719 - 4s - loss: 0.3405 - accuracy: 0.8765 - val_loss: 0.3548 - val_accuracy: 0.8688 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1719/1719 - 4s - loss: 0.3167 - accuracy: 0.8838 - val_loss: 0.3393 - val_accuracy: 0.8752 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1719/1719 - 4s - loss: 0.2978 - accuracy: 0.8889 - val_loss: 0.3159 - val_accuracy: 0.8860 - 4s/epoch - 2ms/step

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3565 - accuracy: 0.8744 - 561ms/epoch - 2ms/step
#
# Test accuracy: 0.8744000196456909

# %%
# Use the model to make predictions on some test images
predictions = model.predict(x_test)

# Plot the first 25 test images with their predicted labels
plt.figure(figsize=(15,15))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(predictions[i])])
plt.show()

# %% [markdown]
# This was directly copied from OpenAI's ChatGPT.
